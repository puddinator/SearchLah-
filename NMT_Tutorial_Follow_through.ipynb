# %%
import requests
# scr_file = 'https://gist.githubusercontent.com/michelkana/b9ab95e1e44ee297e51ef163dd7302ca/raw/021fc91ceb22ee154ea2b8cb98eb3303c0e22184/yemba_english_sentences.txt'
# scr_file = 'https://raw.githubusercontent.com/puddinator/SearchLah-/main/dataset.txt'

scr_file_en = 'https://nlp.stanford.edu/projects/nmt/data/iwslt15.en-vi/train.en'
req_en = requests.get(scr_file_en)
text_en = req_en.text
# convert to list
lines_en = text_en.strip().split('\n')[:1350]

scr_file_vi = 'https://nlp.stanford.edu/projects/nmt/data/iwslt15.en-vi/train.vi'
req_vi = requests.get(scr_file_vi)
text_vi = req_vi.text
# convert to list
lines_vi = text_vi.strip().split('\n')[:1350]

pairs = [list(x) for x in zip(lines_en, lines_vi)]
# pairs = [line.split(';') for line in lines]
pairs[1]
# Out:
# ['In 4 minutes , atmospheric chemist Rachel Pike provides a glimpse of the massive scientific effort behind the bold headlines on climate change , with her team -- one of thousands who contributed -- taking a risky flight over the rainforest in pursuit of data on a key molecule .',
#  'Trong 4 phút , chuyên gia hoá học khí quyển Rachel Pike giới thiệu sơ lược về những nỗ lực khoa học miệt mài đằng sau những tiêu đề táo bạo về biến đổi khí hậu , cùng với đoàn nghiên cứu của mình -- hàng ngàn người đã cống hiến cho dự án này -- một chuyến bay mạo hiểm qua rừng già để tìm kiếm thông tin về một phân tử then chốt .']

# %%
from keras.preprocessing.text import Tokenizer
import numpy as np

# convert to array
pairs = np.array(pairs)

# fit a tokenizer
def create_tokenizer(lines):
	tokenizer = Tokenizer()
	tokenizer.fit_on_texts(lines)
	return tokenizer

# max sentence length
def max_length(lines):
	return max(len(line.split()) for line in lines)


en_tokenizer = create_tokenizer(pairs[:, 1])
en_vocab_size = len(en_tokenizer.word_index) + 1
en_length = max_length(pairs[:, 1])
print('English Vocabulary Size: %d' % en_vocab_size)
print('English Max Length: %d' % (en_length))

#English Vocabulary Size: 183
#English Max Length: 18
  
yb_tokenizer = create_tokenizer(pairs[:, 0])
yb_vocab_size = len(yb_tokenizer.word_index) + 1
yb_length = max_length(pairs[:, 0])
print('Yemba Vocabulary Size: %d' % yb_vocab_size)
print('Yemba Max Length: %d' % (yb_length))
# Out:
# English Vocabulary Size: 2144
# English Max Length: 153
# Yemba Vocabulary Size: 3348
# Yemba Max Length: 112

# %%
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np

# encode and pad sequences
def encode_sequences(tokenizer, length, lines):
	# integer encode sequences
	X = tokenizer.texts_to_sequences(lines)
	# pad sequences with 0 values
	X = pad_sequences(X, maxlen=length, padding='post')
	return X

# one hot encode target sequence
def encode_output(sequences, vocab_size):
	ylist = list()
	for sequence in sequences:
		encoded = to_categorical(sequence, num_classes=vocab_size)
		ylist.append(encoded)
	y = np.array(ylist)
	y = y.reshape(sequences.shape[0], sequences.shape[1], vocab_size)
	return y

# shuffle data
dataset = np.array(pairs)
np.random.shuffle(dataset)
train, test = dataset[:1300,:], dataset[1300:,:]

# prepare training data
trainX = encode_sequences(en_tokenizer, en_length, train[:, 1])
trainY = encode_sequences(yb_tokenizer, yb_length, train[:, 0])
trainY = encode_output(trainY, yb_vocab_size)

# prepare validation data
testX = encode_sequences(en_tokenizer, en_length, test[:, 1])
testY = encode_sequences(yb_tokenizer, yb_length, test[:, 0])
testY = encode_output(testY, yb_vocab_size)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Embedding
from tensorflow.keras.layers import RepeatVector
from tensorflow.keras.layers import TimeDistributed

# define seq2seq model
def define_model(src_vocab, tar_vocab, source_steps, target_steps, 
		 embedding_dim):
	model = Sequential()
  	# encoder
	model.add(Embedding(src_vocab, embedding_dim, 
			    input_length=source_steps, mask_zero=True))
	model.add(LSTM(embedding_dim))
	model.add(RepeatVector(target_steps))
  	# decoder
	model.add(LSTM(embedding_dim, return_sequences=True))
	model.add(TimeDistributed(Dense(tar_vocab, activation='softmax')))
	# compile model
	model.compile(optimizer='adam', loss='categorical_crossentropy')
	# summarize defined model
	model.summary()
	return model

model = define_model(
	en_vocab_size, yb_vocab_size, en_length, yb_length, 256)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 153, 256)          548864
#
#  lstm (LSTM)                 (None, 256)               525312
#
#  repeat_vector (RepeatVector  (None, 112, 256)         0
#  )
#
#  lstm_1 (LSTM)               (None, 112, 256)          525312
#
#  time_distributed (TimeDistr  (None, 112, 3348)        860436
#  ibuted)
#
# =================================================================
# Total params: 2,459,924
# Trainable params: 2,459,924
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

checkpoint = ModelCheckpoint('model_en_yb.h5', monitor='val_loss', 
                              verbose=1, save_best_only=True, mode='min')
history = model.fit(trainX, trainY, epochs=100, batch_size=16, 
                    validation_data=(testX, testY), 
                    callbacks=[checkpoint], verbose=2)
# Out:
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 1.08380, saving model to model_en_yb.h5
# 82/82 - 15s - loss: 2.1498 - val_loss: 1.0838 - 15s/epoch - 179ms/step
# Epoch 2/100
#
# Epoch 2: val_loss did not improve from 1.08380
# 82/82 - 3s - loss: 1.1995 - val_loss: 1.2142 - 3s/epoch - 34ms/step
# Epoch 3/100
#
# Epoch 3: val_loss did not improve from 1.08380
# 82/82 - 3s - loss: 1.1455 - val_loss: 1.1637 - 3s/epoch - 34ms/step
# Epoch 4/100
#
# Epoch 4: val_loss did not improve from 1.08380
# 82/82 - 3s - loss: 1.1079 - val_loss: 1.1417 - 3s/epoch - 34ms/step
# Epoch 5/100
#
# Epoch 5: val_loss improved from 1.08380 to 0.98008, saving model to model_en_yb.h5
# 82/82 - 3s - loss: 1.2289 - val_loss: 0.9801 - 3s/epoch - 35ms/step
# Epoch 6/100
#
# Epoch 6: val_loss improved from 0.98008 to 0.95047, saving model to model_en_yb.h5
# 82/82 - 3s - loss: 1.0568 - val_loss: 0.9505 - 3s/epoch - 35ms/step
# Epoch 7/100
#
# Epoch 7: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 1.0312 - val_loss: 1.1798 - 3s/epoch - 34ms/step
# Epoch 8/100
#
# Epoch 8: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 1.0391 - val_loss: 0.9739 - 3s/epoch - 34ms/step
# Epoch 9/100
#
# Epoch 9: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 1.0110 - val_loss: 0.9678 - 3s/epoch - 33ms/step
# Epoch 10/100
#
# Epoch 10: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 1.0106 - val_loss: 0.9665 - 3s/epoch - 34ms/step
# Epoch 11/100
#
# Epoch 11: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 1.0026 - val_loss: 0.9716 - 3s/epoch - 34ms/step
# Epoch 12/100
#
# Epoch 12: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.9969 - val_loss: 0.9794 - 3s/epoch - 34ms/step
# Epoch 13/100
#
# Epoch 13: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.9926 - val_loss: 0.9958 - 3s/epoch - 36ms/step
# Epoch 14/100
#
# Epoch 14: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.9982 - val_loss: 0.9708 - 3s/epoch - 34ms/step
# Epoch 15/100
#
# Epoch 15: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.9867 - val_loss: 0.9776 - 3s/epoch - 34ms/step
# Epoch 16/100
#
# Epoch 16: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.9811 - val_loss: 0.9802 - 3s/epoch - 34ms/step
# Epoch 17/100
#
# Epoch 17: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.9800 - val_loss: 0.9897 - 3s/epoch - 34ms/step
# Epoch 18/100
#
# Epoch 18: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.9789 - val_loss: 0.9937 - 3s/epoch - 34ms/step
# Epoch 19/100
#
# Epoch 19: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.9779 - val_loss: 0.9851 - 3s/epoch - 33ms/step
# Epoch 20/100
#
# Epoch 20: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.9691 - val_loss: 0.9875 - 3s/epoch - 34ms/step
# Epoch 21/100
#
# Epoch 21: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.9708 - val_loss: 0.9880 - 3s/epoch - 34ms/step
# Epoch 22/100
#
# Epoch 22: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.9636 - val_loss: 1.0036 - 3s/epoch - 33ms/step
# Epoch 23/100
#
# Epoch 23: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.9652 - val_loss: 0.9937 - 3s/epoch - 34ms/step
# Epoch 24/100
#
# Epoch 24: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.9614 - val_loss: 0.9883 - 3s/epoch - 34ms/step
# Epoch 25/100
#
# Epoch 25: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.9572 - val_loss: 0.9897 - 3s/epoch - 34ms/step
# Epoch 26/100
#
# Epoch 26: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.9531 - val_loss: 0.9896 - 3s/epoch - 34ms/step
# Epoch 27/100
#
# Epoch 27: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.9488 - val_loss: 0.9972 - 3s/epoch - 34ms/step
# Epoch 28/100
#
# Epoch 28: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.9468 - val_loss: 1.0171 - 3s/epoch - 33ms/step
# Epoch 29/100
#
# Epoch 29: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.9502 - val_loss: 0.9956 - 3s/epoch - 34ms/step
# Epoch 30/100
#
# Epoch 30: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.9450 - val_loss: 1.0004 - 3s/epoch - 34ms/step
# Epoch 31/100
#
# Epoch 31: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.9408 - val_loss: 0.9977 - 3s/epoch - 33ms/step
# Epoch 32/100
#
# Epoch 32: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.9385 - val_loss: 1.0099 - 3s/epoch - 33ms/step
# Epoch 33/100
#
# Epoch 33: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.9452 - val_loss: 0.9983 - 3s/epoch - 33ms/step
# Epoch 34/100
#
# Epoch 34: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.9332 - val_loss: 1.0127 - 3s/epoch - 33ms/step
# Epoch 35/100
#
# Epoch 35: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.9328 - val_loss: 1.0089 - 3s/epoch - 33ms/step
# Epoch 36/100
#
# Epoch 36: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.9299 - val_loss: 1.0225 - 3s/epoch - 34ms/step
# Epoch 37/100
#
# Epoch 37: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.9236 - val_loss: 1.0248 - 3s/epoch - 33ms/step
# Epoch 38/100
#
# Epoch 38: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.9268 - val_loss: 1.0080 - 3s/epoch - 33ms/step
# Epoch 39/100
#
# Epoch 39: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.9196 - val_loss: 1.0266 - 3s/epoch - 34ms/step
# Epoch 40/100
#
# Epoch 40: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.9199 - val_loss: 1.0210 - 3s/epoch - 34ms/step
# Epoch 41/100
#
# Epoch 41: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.9163 - val_loss: 1.0181 - 3s/epoch - 34ms/step
# Epoch 42/100
#
# Epoch 42: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.9137 - val_loss: 1.0288 - 3s/epoch - 33ms/step
# Epoch 43/100
#
# Epoch 43: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.9191 - val_loss: 1.0178 - 3s/epoch - 33ms/step
# Epoch 44/100
#
# Epoch 44: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.9080 - val_loss: 1.0156 - 3s/epoch - 33ms/step
# Epoch 45/100
#
# Epoch 45: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.9033 - val_loss: 1.0207 - 3s/epoch - 33ms/step
# Epoch 46/100
#
# Epoch 46: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.9073 - val_loss: 1.0256 - 3s/epoch - 33ms/step
# Epoch 47/100
#
# Epoch 47: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.9006 - val_loss: 1.0266 - 3s/epoch - 33ms/step
# Epoch 48/100
#
# Epoch 48: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.8917 - val_loss: 1.0304 - 3s/epoch - 34ms/step
# Epoch 49/100
#
# Epoch 49: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.8840 - val_loss: 1.0243 - 3s/epoch - 34ms/step
# Epoch 50/100
#
# Epoch 50: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.8790 - val_loss: 1.0492 - 3s/epoch - 33ms/step
# Epoch 51/100
#
# Epoch 51: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.8806 - val_loss: 1.0458 - 3s/epoch - 34ms/step
# Epoch 52/100
#
# Epoch 52: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.8761 - val_loss: 1.0398 - 3s/epoch - 34ms/step
# Epoch 53/100
#
# Epoch 53: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.8686 - val_loss: 1.0390 - 3s/epoch - 34ms/step
# Epoch 54/100
#
# Epoch 54: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.8671 - val_loss: 1.0462 - 3s/epoch - 34ms/step
# Epoch 55/100
#
# Epoch 55: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.8638 - val_loss: 1.0416 - 3s/epoch - 34ms/step
# Epoch 56/100
#
# Epoch 56: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.8659 - val_loss: 1.0462 - 3s/epoch - 33ms/step
# Epoch 57/100
#
# Epoch 57: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.8636 - val_loss: 1.0485 - 3s/epoch - 33ms/step
# Epoch 58/100
#
# Epoch 58: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.8500 - val_loss: 1.0580 - 3s/epoch - 33ms/step
# Epoch 59/100
#
# Epoch 59: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.8468 - val_loss: 1.0564 - 3s/epoch - 34ms/step
# Epoch 60/100
#
# Epoch 60: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.8419 - val_loss: 1.0576 - 3s/epoch - 34ms/step
# Epoch 61/100
#
# Epoch 61: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.8392 - val_loss: 1.0751 - 3s/epoch - 34ms/step
# Epoch 62/100
#
# Epoch 62: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.8364 - val_loss: 1.0726 - 3s/epoch - 34ms/step
# Epoch 63/100
#
# Epoch 63: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.8320 - val_loss: 1.0769 - 3s/epoch - 34ms/step
# Epoch 64/100
#
# Epoch 64: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.8309 - val_loss: 1.0696 - 3s/epoch - 34ms/step
# Epoch 65/100
#
# Epoch 65: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.8270 - val_loss: 1.0674 - 3s/epoch - 34ms/step
# Epoch 66/100
#
# Epoch 66: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.8257 - val_loss: 1.0757 - 3s/epoch - 34ms/step
# Epoch 67/100
#
# Epoch 67: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.8169 - val_loss: 1.0826 - 3s/epoch - 34ms/step
# Epoch 68/100
#
# Epoch 68: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.8123 - val_loss: 1.0841 - 3s/epoch - 34ms/step
# Epoch 69/100
#
# Epoch 69: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.8087 - val_loss: 1.0822 - 3s/epoch - 33ms/step
# Epoch 70/100
#
# Epoch 70: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.8055 - val_loss: 1.0932 - 3s/epoch - 34ms/step
# Epoch 71/100
#
# Epoch 71: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.7968 - val_loss: 1.0966 - 3s/epoch - 34ms/step
# Epoch 72/100
#
# Epoch 72: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.7940 - val_loss: 1.0963 - 3s/epoch - 34ms/step
# Epoch 73/100
#
# Epoch 73: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.7918 - val_loss: 1.0985 - 3s/epoch - 34ms/step
# Epoch 74/100
#
# Epoch 74: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.7831 - val_loss: 1.0996 - 3s/epoch - 34ms/step
# Epoch 75/100
#
# Epoch 75: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.7745 - val_loss: 1.1074 - 3s/epoch - 34ms/step
# Epoch 76/100
#
# Epoch 76: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.7736 - val_loss: 1.1111 - 3s/epoch - 34ms/step
# Epoch 77/100
#
# Epoch 77: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.7671 - val_loss: 1.1029 - 3s/epoch - 34ms/step
# Epoch 78/100
#
# Epoch 78: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.7622 - val_loss: 1.1210 - 3s/epoch - 34ms/step
# Epoch 79/100
#
# Epoch 79: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.7535 - val_loss: 1.1070 - 3s/epoch - 34ms/step
# Epoch 80/100
#
# Epoch 80: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.7477 - val_loss: 1.1000 - 3s/epoch - 34ms/step
# Epoch 81/100
#
# Epoch 81: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.7472 - val_loss: 1.1120 - 3s/epoch - 34ms/step
# Epoch 82/100
#
# Epoch 82: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.7421 - val_loss: 1.1167 - 3s/epoch - 33ms/step
# Epoch 83/100
#
# Epoch 83: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.7351 - val_loss: 1.1054 - 3s/epoch - 34ms/step
# Epoch 84/100
#
# Epoch 84: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.7301 - val_loss: 1.1123 - 3s/epoch - 33ms/step
# Epoch 85/100
#
# Epoch 85: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.7216 - val_loss: 1.1180 - 3s/epoch - 34ms/step
# Epoch 86/100
#
# Epoch 86: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.7158 - val_loss: 1.1118 - 3s/epoch - 34ms/step
# Epoch 87/100
#
# Epoch 87: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.7043 - val_loss: 1.1269 - 3s/epoch - 34ms/step
# Epoch 88/100
#
# Epoch 88: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.6974 - val_loss: 1.1225 - 3s/epoch - 34ms/step
# Epoch 89/100
#
# Epoch 89: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.6926 - val_loss: 1.1363 - 3s/epoch - 34ms/step
# Epoch 90/100
#
# Epoch 90: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.6907 - val_loss: 1.1404 - 3s/epoch - 35ms/step
# Epoch 91/100
#
# Epoch 91: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.6844 - val_loss: 1.1248 - 3s/epoch - 34ms/step
# Epoch 92/100
#
# Epoch 92: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.6890 - val_loss: 1.1215 - 3s/epoch - 35ms/step
# Epoch 93/100
#
# Epoch 93: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.6732 - val_loss: 1.1222 - 3s/epoch - 34ms/step
# Epoch 94/100
#
# Epoch 94: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.6592 - val_loss: 1.1311 - 3s/epoch - 34ms/step
# Epoch 95/100
#
# Epoch 95: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.6566 - val_loss: 1.1285 - 3s/epoch - 34ms/step
# Epoch 96/100
#
# Epoch 96: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.6474 - val_loss: 1.1423 - 3s/epoch - 34ms/step
# Epoch 97/100
#
# Epoch 97: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.6442 - val_loss: 1.1571 - 3s/epoch - 34ms/step
# Epoch 98/100
#
# Epoch 98: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.6367 - val_loss: 1.1372 - 3s/epoch - 34ms/step
# Epoch 99/100
#
# Epoch 99: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.6308 - val_loss: 1.1547 - 3s/epoch - 34ms/step
# Epoch 100/100
#
# Epoch 100: val_loss did not improve from 0.95047
# 82/82 - 3s - loss: 0.6253 - val_loss: 1.1433 - 3s/epoch - 34ms/step

# %%
from numpy import argmax
from nltk.translate.bleu_score import corpus_bleu

# map an integer to a word
def word_for_id(integer, tokenizer):
	for word, index in tokenizer.word_index.items():
		if index == integer:
			return word
	return None
  
# generate target given source sequence
def predict_sequence(model, tokenizer, source):
	prediction = model.predict(source, verbose=0)[0]
	integers = [argmax(vector) for vector in prediction]
	target = list()
	for i in integers:
		word = word_for_id(i, tokenizer)
		if word is None:
			break
		target.append(word)
	return ' '.join(target)

# %%
# evaluate the model
def evaluate_model(model, sources, raw_dataset):
	actual, predicted = list(), list()
	for i, source in enumerate(sources):
		# translate encoded source text
		source = source.reshape((1, source.shape[0]))
		translation = predict_sequence(model, yb_tokenizer, source)
		raw_target, raw_src = raw_dataset[i]
		if i < 10:
			print('src=[%s], target=[%s], predicted=[%s]' % (raw_src, raw_target, translation))
		actual.append(raw_target.split())
		predicted.append(translation.split())
	# calculate BLEU score
	print('BLEU-1: %f' % corpus_bleu(actual, predicted, weights=(1.0, 0, 0, 0)))
	print('BLEU-2: %f' % corpus_bleu(actual, predicted, weights=(0.5, 0.5, 0, 0)))
	print('BLEU-3: %f' % corpus_bleu(actual, predicted, weights=(0.3, 0.3, 0.3, 0)))
	# print('BLEU-4: %f' % corpus_bleu(actual, predicted, weights=(0.25, 0.25, 0.25, 0.25)))
	
evaluate_model(model, testX, test)
# Out:
# src=[Nhưng dù sao , đây là -- thực phẩm , tại trung tâm của cuộc sống , trung tâm của cuộc sống gia đình , đang được bày ra , thưởng thức , mọi người dành thời gian cho chúng .], target=[But anyway , this is -- it &apos;s food at the center of life , at the center of family life , being celebrated , being enjoyed , people taking time for it .], predicted=[and the the the the the the the the the the the the the the the the the the the the]
# src=[Các nhà khoa học phải được thắt chặt hoàn toàn vào ghế để có thể thực hiện đo đạc trên máy bay .], target=[And the scientists have to be completely harnessed in in order to make measurements while they &apos;re on board .], predicted=[and is the fraction the unfortunately older older most recycled and members grandparents]
# src=[Nó chỉ cần tuân thủ những quy tắc an toàn .], target=[It just has to follow safety guidelines .], predicted=[it it s emotion emotion]
# src=[Bao nhiêu người trong số bạn đã giành chiến thắng ?], target=[How many of you won just won thumb ?], predicted=[and is geeks a me me]
# src=[Một nhà biohacker người Đức , một nhà báo , muốn biết chó của ai đã để lại những &quot; món quà &quot; nho nhỏ trên đường ?], target=[A biohacker in Germany , a journalist , wanted to know whose dog was leaving little presents on his street ?], predicted=[the the of the the the the the the the the we that that to to to to]
# src=[Nhưng ta không thấy nó trên truyền thông , đúng không ?], target=[But we don &apos;t see it on social media , right ?], predicted=[and apos apos apos t t for for]
# src=[Và đó cũng là vấn đề đang gia tăng .], target=[And it &apos;s an escalating problem too .], predicted=[it it apos s a a wondrous]
# src=[Vậy ai là người sẽ thực hiện nó ?], target=[So who gets to do it ?], predicted=[so can can can can quot]
# src=[nhưng hầu hết là nắp chai .], target=[but , mostly bottle caps .], predicted=[so can the of of of the]
# src=[Bạn có thể thả khí cầu thời tiết lên tầng tĩnh khí , thu thập vi khuẩn , xem điều gì đang xảy ra trên đó .], target=[You can send weather balloons up into the stratosphere , collect microbes , see what &apos;s up there .], predicted=[and apos you to the the the the the the the the the the the the to to the the the]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-6e25a3c31b54> in <module>
#      17         # print('BLEU-4: %f' % corpus_bleu(actual, predicted, weights=(0.25, 0.25, 0.25, 0.25)))
#      18
# ---> 19 evaluate_model(model, testX, test)
#
# <ipython-input-8-6e25a3c31b54> in evaluate_model(model, sources, raw_dataset)
#      12                 predicted.append(translation.split())
#      13         # calculate BLEU score
# ---> 14         print('BLEU-1: %f' % corpus_bleu(actual, predicted, weights=(1.0, 0, 0, 0)))
#      15         print('BLEU-2: %f' % corpus_bleu(actual, predicted, weights=(0.5, 0.5, 0, 0)))
#      16         print('BLEU-3: %f' % corpus_bleu(actual, predicted, weights=(0.3, 0.3, 0.3, 0)))
#
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py in corpus_bleu(list_of_references, hypotheses, weights, smoothing_function, auto_reweigh)
#     208         # denominator for the corpus-level modified precision.
#     209         for i in range(1, max_weight_length + 1):
# --> 210             p_i = modified_precision(references, hypothesis, i)
#     211             p_numerators[i] += p_i.numerator
#     212             p_denominators[i] += p_i.denominator
#
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py in modified_precision(references, hypothesis, n)
#     358     # Assigns the intersection between hypothesis and references' counts.
#     359     clipped_counts = {
# --> 360         ngram: min(count, max_counts[ngram]) for ngram, count in counts.items()
#     361     }
#     362
#
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py in <dictcomp>(.0)
#     358     # Assigns the intersection between hypothesis and references' counts.
#     359     clipped_counts = {
# --> 360         ngram: min(count, max_counts[ngram]) for ngram, count in counts.items()
#     361     }
#     362
#
# KeyError: ('cows',)
